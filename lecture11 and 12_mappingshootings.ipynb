# %% [markdown]
# # Lecture 11 Mapping Shootings
# - Name: Mahir Dalal
# - Division: B

# %%
# Stetup cell
import pandas as pd

# %%
# Importing the Mass Shooting Data of 2016 into our Notebook
shootings_df=pd.read_csv("Mass-Shooting-Data-2016.csv")
shootings_df
# Out:
#           date         city                 state  injured  killed        lat  \
# 0     3-Nov-16      Chicago              Illinois        2       2  41.875555
# 1     2-Nov-16  Little Rock              Arkansas        4       0  34.746481
# 2     1-Nov-16      Memphis             Tennessee        5       1  35.149022
# 3    31-Oct-16   Shreveport             Louisiana        4       0  32.522183
# 4    30-Oct-16       Toledo                  Ohio        4       0  41.678675
# ..         ...          ...                   ...      ...     ...        ...
# 320  11-Jan-16   Wilmington              Delaware        4       1  39.745947
# 321   8-Jan-16   Washington  District of Columbia        4       0  38.894955
# 322   8-Jan-16      Chicago              Illinois        4       1  41.875555
# 323   7-Jan-16      Memphis             Tennessee        3       1  35.149022
# 324   6-Jan-16     Lakeland               Florida        1       3  28.039465
#
#            lng
# 0   -87.624421
# ...

# %%
# First 10 rows of the DataFrame
shootings_df.head(10)
# Out:
#         date                  city      state  injured  killed        lat  \
# 0   3-Nov-16               Chicago   Illinois        2       2  41.875555
# 1   2-Nov-16           Little Rock   Arkansas        4       0  34.746481
# 2   1-Nov-16               Memphis  Tennessee        5       1  35.149022
# 3  31-Oct-16            Shreveport  Louisiana        4       0  32.522183
# 4  30-Oct-16                Toledo       Ohio        4       0  41.678675
# 5  30-Oct-16              Newburgh   New York        5       2  41.503427
# 6  30-Oct-16  New York (Manhattan)   New York        4       0  40.748436
# 7  30-Oct-16       Capitol Heights   Maryland        4       2  38.885396
# 8  30-Oct-16           San Antonio      Texas        5       0  29.424600
# 9  29-Oct-16                Dayton       Ohio        3       1  39.758948
#
#          lng
# 0 -87.624421
# 1 -92.289595
# 2 -90.051628
# 3 -93.765194
# 4 -83.512728
# 5 -74.010418
# 6 -73.985693
# 7 -76.915944
# 8 -98.495140
# ...

# %%
# Averagre injuries and average killed by state and city
average_injuries_killed_df=shootings_df.groupby(["state","city"]).agg(avg_injuries=("injured","mean"),avg_killed=("killed","mean"))
average_injuries_killed_df
# Out:
#                                    avg_injuries  avg_killed
# state         city
# Alabama       Anniston                      4.0         0.0
#               Auburn                        1.0         3.0
#               Bessemer                      3.0         1.0
#               Bessemer (Brighton)           6.0         1.0
#               Birmingham                    4.0         1.0
# ...                                         ...         ...
# Washington    Seattle                       3.0         2.0
#               Tacoma                        5.0         0.0
#               Woodland                      1.0         3.0
# West Virginia Charleston                    3.0         1.0
# Wisconsin     Milwaukee                     2.5         1.5
#
# [194 rows x 2 columns]

# %%
# Total injuries and total killed by state and city
total_injuries_killed_df=shootings_df.groupby(["state","city"]).agg(injuries=("injured","sum"),killed=("killed","sum"))
total_injuries_killed_df
# Out:
#                                    injuries  killed
# state         city
# Alabama       Anniston                    4       0
#               Auburn                      1       3
#               Bessemer                    3       1
#               Bessemer (Brighton)         6       1
#               Birmingham                  4       1
# ...                                     ...     ...
# Washington    Seattle                     3       2
#               Tacoma                      5       0
#               Woodland                    1       3
# West Virginia Charleston                  3       1
# Wisconsin     Milwaukee                   5       3
#
# [194 rows x 2 columns]

# %%
# Sort by killed column in ascending
total_injuries_killed_df.sort_values("killed",ascending=True)
# Out:
#                           injuries  killed
# state      city
# Alabama    Anniston              4       0
# New Jersey Willingboro           4       0
# New York   Bronx                 4       0
# Florida    Miami Gardens         4       0
# New York   Brooklyn             24       0
# ...                            ...     ...
# Arizona    Glendale              5       8
# Ohio       Piketon               0       8
# Texas      Houston              31      10
# Illinois   Chicago              87      11
# Florida    Orlando              77      55
#
# [194 rows x 2 columns]

# %%
# Sort by killed column in decending
total_injuries_killed_df.sort_values("killed",ascending=False)
# Out:
#                                  injuries  killed
# state      city
# Florida    Orlando                     77      55
# Illinois   Chicago                     87      11
# Texas      Houston                     31      10
# California Los Angeles                 36       8
# Arizona    Glendale                     5       8
# ...                                   ...     ...
# New York   New York (Manhattan)         8       0
#            Elmira                       5       0
#            Corona (Queens)              4       0
#            Brooklyn                    24       0
# Alabama    Anniston                     4       0
#
# [194 rows x 2 columns]

# %%
# Top 5 cities DataFrame in the US with the most killed
top_5_cities_killed=total_injuries_killed_df.sort_values("killed",ascending=False).head(5)
top_5_cities_killed
# Out:
#                         injuries  killed
# state      city
# Florida    Orlando            77      55
# Illinois   Chicago            87      11
# Texas      Houston            31      10
# California Los Angeles        36       8
# Arizona    Glendale            5       8

# %% [markdown]
# # Challenge(5 Points): Top 5 states in US with the most injuries

# %%
state_injuries_df=shootings_df.groupby(["state"]).agg(injuries=("injured","sum"))
top_5_state_injuries_df=state_injuries_df.sort_values("injuries",ascending=False).head(5)
top_5_state_injuries_df
# Out:
#             injuries
# state
# Florida          169
# California       155
# Illinois         127
# Texas             94
# New York          57

# %% [markdown]
# # 2016 Mass Shooting Report

# %%
# Total Injuries
total_injuries=shootings_df.injured.sum()
total_injuries
# Out:
# 1311

# %%
# Total Killed
total_killed=shootings_df.killed.sum()
total_killed
# Out:
# 400

# %% [markdown]
# # Challenge(2 points): Create and print a variable that says"In 2016, there were 1311 injuries, and 400 people killed, due to mass-shootings."

# %%
sentence="In 2016, there were "+str(total_injuries)+" injuries,and "+str(total_killed)+" people killed,due to mass-shootings"
sentence
# Out:
# 'In 2016, there were 1311 injuries,and 400 people killed,due to mass-shootings'

# %% [markdown]
# # Metric: Which cities need more attention

# %%
# Break out room task-idea my team came up with
cities_need_attention_df=shootings_df.groupby(["city"]).agg(injuries=("injured","mean"),killed=("killed","mean"))
attention_required_df=cities_need_attention_df.sort_values("injuries",ascending=False).head(5)
attention_required_df=cities_need_attention_df.sort_values("killed",ascending=False).head(5)
attention_required_df
# Out:
#             injuries  killed
# city
# Orlando         15.4    11.0
# Piketon          0.0     8.0
# Chesapeake       0.0     6.0
# Appling          0.0     6.0
# Kalamazoo        2.0     6.0

# %%
# making a matrix
# Creating a column called persons involved in shootings df
shootings_df["persons_involved"]=shootings_df["injured"]+shootings_df["killed"]
# Creating a city dataframe to caluclate total persons involoved and total incidents per city
city_df= shootings_df.groupby(['state',"city"]).agg(total_persons_involved=("persons_involved","sum"),
                                                    total_incidents=("city","count"))
# Creating a column to calculate tital persons per incident
city_df["persons_involved_per_incident"]=city_df["total_persons_involved"]/city_df["total_incidents"]
# Creating our final z-Index DataFrame which shows only cities which have atleast 5 persons involved per incident
z_index_df= city_df.loc[city_df["persons_involved_per_incident"]>=5].sort_values("persons_involved_per_incident",ascending=False)
z_index_df
# Out:
#                                             total_persons_involved  \
# state       city
# Florida     Orlando                                            132
# Kansas      Hesston                                             18
# California  Bakersfield                                         15
# Connecticut Bridgeport                                          13
# Florida     Fort Myers                                          25
# ...                                                            ...
# Alabama     Birmingham                                           5
# Maryland    District Heights (Forestville)                       5
# Michigan    Berrien (county)                                     5
#             Saginaw                                              5
# Washington  Tacoma                                               5
#
#                                             total_incidents  \
# state       city
# Florida     Orlando                                       5
# ...

# %% [markdown]
# # Challenge(5 points): Implement the Hoz index
# - Filter for incidents in which there were atleast 1 person killed
# - sort in decending order to see cities with the maximum incidents in which there was atleast 1 person killed

# %%
# Filter for incidents in which there were atleast 1 person killed
atleast_1_killed_df=shootings_df.loc[shootings_df["killed"]>1]
atleast_1_killed_df
# Out:
#           date                    city       state  injured  killed  \
# 0     3-Nov-16                 Chicago    Illinois        2       2
# 5    30-Oct-16                Newburgh    New York        5       2
# 7    30-Oct-16         Capitol Heights    Maryland        4       2
# 14   27-Oct-16  Mcdonough (Mc Donough)     Georgia        0       4
# 16   25-Oct-16                 Roanoke    Virginia        3       2
# ..         ...                     ...         ...      ...     ...
# 314  30-Jan-16                Glendale     Arizona        5       3
# 315  27-Jan-16              Chesapeake    Virginia        0       6
# 316  26-Jan-16                 Seattle  Washington        3       2
# 318  23-Jan-16             Los Angeles  California        2       2
# 324   6-Jan-16                Lakeland     Florida        1       3
#
#            lat         lng  persons_involved
# 0    41.875555  -87.624421                 4
# 5    41.503427  -74.010418                 7
# ...

# %%
#sort in decending order to see cities with the maximum incidents in which there was atleast 1 person killed
hoz_city_df= atleast_1_killed_df.groupby(["state","city"]).agg(total_incidents=("city","count"))
hoz_city_df.sort_values("total_incidents",ascending=False)
# Out:
#                             total_incidents
# state     city
# Illinois  Chicago                         3
# Florida   Orlando                         3
# Texas     Houston                         2
# Arizona   Glendale                        2
#           Phoenix                         2
# ...                                     ...
# Maryland  Bethesda                        1
#           Capitol Heights                 1
# Alabama   Citronelle                      1
# Michigan  Berrien (county)                1
# Wisconsin Milwaukee                       1
#
# [74 rows x 1 columns]

# %% [markdown]
# # Kha Index
# - Find the average (aka the mean) persons involved per incident
# - List the cities that exceed the average(aka the mean) persons involved per incident

# %%
# Average persons involved per incident
avg_persons_involved_per_incident=shootings_df.persons_involved.mean()
avg_persons_involved_per_incident
# Out:
# 5.264615384615385

# %%
city_df.loc[city_df["persons_involved_per_incident"]>=avg_persons_involved_per_incident]
# Out:
#                                         total_persons_involved  \
# state         city
# Alabama       Bessemer (Brighton)                            7
# Arizona       Glendale                                      13
#               Phoenix                                       15
# California    Bakersfield                                   15
#               Compton                                        9
#               Los Angeles                                   44
# Connecticut   Bridgeport                                    13
# Florida       Cape Coral                                     6
#               Fort Myers                                    25
#               Jacksonville                                  11
#               Orlando                                      132
#               Tampa                                         12
# Georgia       Appling                                        6
#               Athens                                         7
# ...

# %% [markdown]
# # Data Visualization(Bar Charts)
#
# **Make a barchart that shows me top 5 cities by killed**

# %%
# Data Viz Setup
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bar_chart_df=shootings_df.groupby(["state","city"]).agg(killed=("killed","sum"))
bar_chart_df=bar_chart_df.sort_values("killed",ascending=False).head(5).reset_index()
bar_chart_df
# Out:
#         state         city  killed
# 0     Florida      Orlando      55
# 1    Illinois      Chicago      11
# 2       Texas      Houston      10
# 3  California  Los Angeles       8
# 4     Arizona     Glendale       8

# %%
sns.barplot(x="city",y="killed",data=bar_chart_df)
# Out:
# <AxesSubplot:xlabel='city', ylabel='killed'>

# %% [markdown]
# # Challenge(3 points):Make a barchart that shows me top 5 cities by injured

# %%
bar_chart_df=shootings_df.groupby(["state","city"]).agg(injured=("injured","sum"))
bar_chart_df=bar_chart_df.sort_values("injured",ascending=False).head(5).reset_index()
bar_chart_df
# Out:
#         state         city  injured
# 0    Illinois      Chicago       87
# 1     Florida      Orlando       77
# 2  California  Los Angeles       36
# 3       Texas      Houston       31
# 4  California      Oakland       27

# %%
sns.barplot(x="city",y="injured",data=bar_chart_df)
# Out:
# <AxesSubplot:xlabel='city', ylabel='injured'>

# %% [markdown]
# # Challenge(3 points):Make a barchart that shows me top 10 states by injured

# %%
bar_chart_df=shootings_df.groupby(["state"]).agg(injured=("injured","sum"))
bar_chart_df=bar_chart_df.sort_values("injured",ascending=False).head(10).reset_index()
bar_chart_df
# Out:
#         state  injured
# 0     Florida      169
# 1  California      155
# 2    Illinois      127
# 3       Texas       94
# 4    New York       57
# 5     Georgia       51
# 6     Alabama       46
# 7   Tennessee       43
# 8    Michigan       43
# 9   Louisiana       41

# %%
sns.set(rc={'figure.figsize':(15,5)})
        
        
sns.barplot(x="state",y="injured",data=bar_chart_df,color="#d63031")
# Out:
# <AxesSubplot:xlabel='state', ylabel='injured'>
